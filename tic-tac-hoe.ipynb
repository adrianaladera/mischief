# %%
import numpy as np

# %%
board = [['', '', ''],
         ['', '', ''],
         ['', '', '']]

for row in board:
    print("|".join(row))
# Out:
# ||
# ||
# ||

# %%
def wiener(board):
    def check_rows():
        for thing in board:
            l = len(thing)
            if thing == l * thing[0] or thing == l * thing[1] or thing == l * thing[2]: # if same
                return True
    
    def hoetate(board):
        rotated_bc_jeff_is_a_STINKY_HOMOPHOBIC_DUNE_WORM = []
        for i in range(len(board)):
            rotated_bc_jeff_is_a_STINKY_HOMOPHOBIC_DUNE_WORM.append([row[i] for row in board])
        return rotated_bc_jeff_is_a_STINKY_HOMOPHOBIC_DUNE_WORM

    if check_rows(board) or check_rows(hoetate(board)):
        return True

# %%
adriana_has_a_wiener = False
player_turn = ""
while not adriana_has_a_wiener:
    x =  input("Choose your character: O or X?")
    while (x.upper() != 'O' and x.upper() != 'X'):
        # if x.upper() != 'O' and x.upper() != 'X':
        print("That is not an option BITCH try again")
        x =  input("Choose your character: O or X?")

    sex_positions, hoe_positions = [], []
    position = input("Where tf do you wanna put this bihh (position 1 - 9): ")
    while (int(position) > 9 or int(position) < 0):
        print("naur you have to pick one that's in the RANGE BRUH")
        position = input("Where tf do you wanna put this bihh (position 1 - 9): ")

    if x.upper == 'O':
        hoe_positions.append(position)
    else:
        sex_positions.append(position)


    # board[int(position)] = / x.upper()
    index = 1
    for i in range(3):
        for j in range(3):
            if index == int(position):
                board[i][j] = x.upper()
            index += 1
    for row in board:
        print(row)

    adriana_has_a_wiener = wiener(board)

print(f"{player_turn.upper()} won yay")
# Out:
# [['', '', ''], ['O', '', ''], ['', '', '']]

# %%
ass = [[1,2,24],[420,69,666],[12,11,10]]

rotated_bc_jeff_is_a_STINKY_HOMOPHOBIC_DUNE_WORM = []
for i in range(len(ass)):
    rotated_bc_jeff_is_a_STINKY_HOMOPHOBIC_DUNE_WORM.append([row[i] for row in ass])

rotated_bc_jeff_is_a_STINKY_HOMOPHOBIC_DUNE_WORM
# Out:
# [[1, 420, 12], [2, 69, 11], [24, 666, 10]]
